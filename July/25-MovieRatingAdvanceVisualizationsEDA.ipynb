# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv(r"D:\Naresh It Classes\July\24th\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
movies.Genre.cat.categories
#The categories of this categorical.Setting assigns new values to each category (effectively a rename ofeach individual category).
#The assigned value has to be a list-like object. All items must be unique and the number of items in the new categories must be the same as the number of items in the old categories.
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies, x='CriticRating', y='AudienceRating')
plt.show()

# %%
j = sns.jointplot(data = movies, x='CriticRating', y='AudienceRating',kind='hex')
plt.show()

# %%
j = sns.jointplot(data = movies, x='CriticRating', y='AudienceRating',kind='reg')
plt.show()

# %%
j = sns.jointplot(data = movies, x='CriticRating', y='AudienceRating',kind='hist')
plt.show()

# %%
m1 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
m2 = sns.distplot(movies.AudienceRating)
plt.show()

# %% [markdown]
# ### distplot kye only 1 axis dete and its movies.rating
# ### for jointplot we give 2 axis and we give data=movie,x='',y=''

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('whitegrid')
m2 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('dark')
m2 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('white')
m2 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('ticks')
m2 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
m2 = sns.displot(movies.AudienceRating)
plt.show()

# %%
n1=sns.histplot(movies.AudienceRating)
plt.show()

# %%
n2 = sns.histplot(movies.AudienceRating, bins=20)
plt.show()

# %%
n2 = sns.histplot(movies.AudienceRating, bins = 100)
plt.show()

# %%
n2 = sns.histplot(movies.AudienceRating, bins = 5)
plt.show()

# %%
h1 = sns.histplot(movies.BudgetMillions,bins=10)
plt.show()

# %%
h2 = sns.histplot(movies[movies.Genre == 'Drama'].BudgetMillions,bins=10)
plt.show()

# %%
h1 = sns.histplot(movies[movies.Genre == 'Drama'].BudgetMillions,bins=10,label = 'Drama',color = 'blue')
h2 = sns.histplot(movies[movies.Genre == 'Action'].BudgetMillions,bins=10,label = 'Action',color='pink')
h3 = sns.histplot(movies[movies.Genre == 'Thriller'].BudgetMillions,bins=10,label = 'Thriller',color = 'green')
plt.legend()
plt.show()

# %%
h1 = plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions,bins=10,label = 'Drama',color = 'blue')
h2 = plt.hist(movies[movies.Genre == 'Action'].BudgetMillions,bins=10,label = 'Action',color='pink')
h3 = sns.histplot(movies[movies.Genre == 'Thriller'].BudgetMillions,bins=10,label = 'Thriller',color = 'green')
plt.legend()
plt.show()

# %% [markdown]
# ## there graph's design is a little bit different for both
# #### sns made it a little transparent, gave automatic x axis and y axis
# #### matplotlib is solid,didn't give any x and y axis, we are unable to understand it.
# #### so we use sns for clear and better understanding of the graphs

# %%
h1 = sns.histplot(movies[movies.Genre == 'Drama'].BudgetMillions,bins=10,label = 'Drama',color = 'blue')
h2 = sns.histplot(movies[movies.Genre == 'Action'].BudgetMillions,bins=10,label = 'Action',color='pink')
h3 = sns.histplot(movies[movies.Genre == 'Thriller'].BudgetMillions,bins=10,label = 'Thriller',color = 'green')
h4 = sns.histplot(movies[movies.Genre == 'Adventure'].BudgetMillions,bins=10,label = 'Adv',color = 'red')
plt.legend()
plt.show()

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Genre.cat

# %%
plt.hist(
    [movies[movies.Genre == 'Drama'].BudgetMillions,
    movies[movies.Genre == 'Action'].BudgetMillions,
    movies[movies.Genre == 'Thriller'].BudgetMillions,
    movies[movies.Genre == 'Comedy'].BudgetMillions],
    stacked = True
)
plt.show()

# %%
plt.hist(
    [movies[movies.Genre == 'Drama'].BudgetMillions,\
    movies[movies.Genre == 'Action'].BudgetMillions,\
    movies[movies.Genre == 'Thriller'].BudgetMillions,\
    movies[movies.Genre == 'Comedy'].BudgetMillions],
    stacked = True,bins=20
)
plt.show()

# %%
for g in movies.Genre.cat.categories:
    print(g)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
sns.set_style('white')
v1 = sns.lmplot(data = movies, x= 'CriticRating', y='AudienceRating',fit_reg=False,hue = 'Genre')
plt.show()

# %%
sns.set_style('white')
v1 = sns.lmplot(data = movies, x= 'CriticRating', y='AudienceRating',fit_reg=True,hue = 'Genre')
plt.show()

# %%
v1 = sns.lmplot(data = movies, x= 'CriticRating', y='AudienceRating', fit_reg=False,hue = 'Genre',height=20,aspect=1)
plt.show()

# %%
v1 = sns.lmplot(data = movies, x= 'CriticRating', y='AudienceRating', fit_reg=False,hue = 'Genre',height=10,aspect=1)
plt.show()

# %%
k1 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating)
plt.show()

# %%
k1 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade=True, cmap='Reds')
plt.show()

# %%
plt.figure(figsize=(5, 4))
k1 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade=True, cmap='Purples',shade_lowest=False)
plt.show()

# %%
k2 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, thresh=0.5,cmap='Greens_r',fill=True)
plt.show()

# %%
k2 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, thresh=0,cmap='Greens_r',fill=True)
plt.show()

# %%
k2 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, thresh=0.05,cmap='Greens_r',fill=True)
plt.show()

# %% [markdown]
# #### KDE Plot: When thresh=0, the shading will extend to the very edges of where the KDE estimates any density, no matter how small. This results in the entire "blob" of the KDE being filled, making it look like it's shaded everywhere that the density estimation function produces a non-zero value.
#
# #### KDE Plot: When thresh is a positive value, the shading will only begin from that specific density level upwards. Areas with a density lower than this threshold will remain unshaded (transparent). This is usefull for Ignoring "noise", focusing on core trends
#
# #### Low thresh (closer to 0): You're seeing more of the distribution, including the very sparse, outer regions. Like a low water level, it covers more ground.
#
# #### Higher thresh: You're focusing on the denser, more concentrated areas of the distribution, ignoring the "outskirts." Like a higher water level, it only fills the deeper basins.

# %%
k3 = sns.kdeplot(x=movies.BudgetMillions, y= movies.AudienceRating)
plt.show()

# %%
k3 = sns.kdeplot(x=movies.BudgetMillions, y= movies.CriticRating, shade = True,cmap='spring',shade_lowest=True )
plt.show()

# %%
k3 = sns.kdeplot(x=movies.BudgetMillions, y= movies.CriticRating, shade = True,cmap='spring',shade_lowest=False )
plt.show()

# %%
w = sns.boxplot(data=movies,x='Genre', y='CriticRating')
plt.show()

# %%
sns.set_style('dark')
w = sns.boxplot(data=movies,x='Genre', y='CriticRating',palette='viridis')
plt.gca().set_facecolor('black')    # Set the axes background to black

plt.show()

# %%
sns.set_style('dark')
w = sns.boxplot(data=movies,x='Genre', y='CriticRating',palette='Set2')
plt.gcf().set_facecolor('black')    # Set the figure background to black
plt.gca().set_facecolor('black')    # Set the axes background to black
w.tick_params(axis='x', colors='white')  # Change the color of the x-axis and y-axis labels and ticks to white
w.tick_params(axis='y', colors='white')
w.xaxis.label.set_color('white')
w.yaxis.label.set_color('white')
# for spine in w.spines.values():
#     spine.set_edgecolor('white')
plt.show()

# %%
z=sns.violinplot(data=movies,x='Genre',y='CriticRating',palette='Set1')
plt.show()

# %%
ax
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'],x='Year', y='CriticRating',palette='Set3')
plt.show()

# %% [markdown]
# ### Subplots
# Creates a new figure and a grid of subplots (Axes objects) all at once.
# The recommended and most common way to create multiple subplots for most use cases. It's cleaner and more efficient.
# Explicitly creates a new figure for you.
# Takes a figsize argument, which applies to the entire Figure being created.
# Takes 2 arguments for the grid dimensions (e.g., 2, 1 for 2 rows, 1 col). Does not take a subplot index.

# %%
f,ax = plt.subplots(1,2, figsize=(12,6))
plt.show()

# %%
sns.set_style('white')

# %%
f, ax = plt.subplots(1,2, figsize=(12,6))   # f:as the entire canvas or window where your plots (the "Axes") will be draw
k1 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating,ax=ax[0],cmap='Reds',shade=True)
k1 = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticRating,ax=ax[1],cmap='Purples',shade=True)
plt.show()

# %%
f,ax=plt.subplots(2,3,figsize=(15,10))
s1 = sns.boxplot(data=movies[movies.Genre == 'Drama'],x='Year', y='CriticRating',palette='Set3',ax=ax[0,0])
s1.set_title('Drama')

s2 = sns.boxplot(data=movies[movies.Genre == 'Action'],x='Year', y='CriticRating',palette='Set3',ax=ax[0,1])
s2.set_title('Action')

s3 = sns.boxplot(data=movies[movies.Genre == 'Romance'],x='Year', y='CriticRating',palette='Set3',ax=ax[0,2])
s3.set_title('Romance')

s4 = sns.boxplot(data=movies[movies.Genre == 'Adventure'],x='Year', y='CriticRating',palette='Set3',ax=ax[1,0])
s4.set_title('Adv')

s5 = sns.boxplot(data=movies[movies.Genre == 'Comedy'],x='Year', y='CriticRating',palette='Set3',ax=ax[1,1])
s5.set_title('Comedy')

s6 = sns.boxplot(data=movies[movies.Genre == 'Thriller'],x='Year', y='CriticRating',palette='Set3',ax=ax[1,2])
s6.set_title('Thriller')

# plt.tight_layout()
plt.show()

# %% [markdown]
# ### Facet grid
# A FacetGrid is a powerful way to visualize the distribution of one or more variables across the levels of one or more categorical variables. It allows you to create a grid of plots where each plot (or "facet") shows a subset of your data based on the unique values of a categorical variable.
#
# #### Why Use a FacetGrid?
#
# Comparison: It makes it incredibly easy to compare patterns, distributions, or relationships across different subsets of your data. Instead of creating many individual plots manually, a FacetGrid automates the process.
#
# Structure: It provides a highly structured and organized way to present multiple related plots.
#
# Exploratory Data Analysis (EDA): It's a fundamental tool for EDA, allowing you to quickly uncover trends or differences that might be hidden when looking at aggregated data.
#
# Consistency: All plots in the grid share the same axis limits (by default), making comparisons more reliable.
#
# #### Common Scenarios for FacetGrid:
#
# Trends over time for different categories: (e.g., stock prices for different companies over time)
#
# Distribution of a variable across groups: (e.g., age distribution for different demographics)
#
# Relationship between two variables across groups: (e.g., correlation between height and weight for different age groups)

# %%
g = sns.FacetGrid(movies,row='Genre', col='Year', hue='Genre')
plt.show()

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)
plt.show()

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter,'CriticRating','AudienceRating')
plt.show()

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist,'BudgetMillions')
plt.show()

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )
plt.show()

# %% [markdown]
# ### kws = dict(s=50, linewidth=0.5, edgecolor='black')
# * Python dictionary named kws (short for "keyword arguments").
# * s-> controls the size of the scatter points. So, each point will have a size of 50.
# * linewidth=0.5: This controls the width of the outline around each scatter point.
# * edgecolor='black': This sets the color of the outline around each scatter point to black.
# * Purpose: This dictionary holds additional keyword arguments that you want to pass to the plotting function that g.map() will use. It's a clean way to organize multiple arguments.
# * **kws: This is the "unpacking operator". It takes all the key-value pairs from your kws dictionary and passes them as individual keyword arguments to the plt.scatter function. So, plt.scatter will receive s=50, linewidth=0.5, and edgecolor='black'.

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.05,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )
plt.show()

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=10, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )
plt.show()

# %%
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax = axes[0,1],color='Red')

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

k3 = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating',palette='Set1' ,ax=axes[1,0])
k4 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
# k4b = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating,cmap='Reds',ax = axes[1,1])

plt.show()

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax = axes[0,1],color='Red')

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

k3 = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating',palette='Set1' ,ax=axes[1,0])
k4 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
k4b = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating,cmap='Reds',ax = axes[1,1])
# k4b overrides k4,, so no use

plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f,axes = plt.subplots(2,2,figsize=(15,15))

k1 = sns.kdeplot(x = movies.BudgetMillions,
                y = movies.AudienceRating,
                shade = True,
                shade_lowest = True,
                cmap = 'Blues',  
                ax = axes[0,0])

k2 = sns.kdeplot(x=movies.BudgetMillions,
                 y=movies.CriticRating,
                shade = True,
                shade_lowest = True,
                cmap = 'inferno',
                ax = axes[0,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

k3 = sns.violinplot(data=movies[movies.Genre=='Drama'],
                   x = 'Year', y = 'CriticRating',palette='Set1',
                   ax = axes[1,0])
k4 = sns.kdeplot(x = movies.CriticRating,
                y = movies.AudienceRating,
                shade = True, thresh = 0, cmap = 'Blues_r',ax = axes[1,1])

plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f,axes = plt.subplots(2,2,figsize=(15,15))

k1 = sns.kdeplot(x = movies.BudgetMillions,
                y = movies.AudienceRating,
                shade = True,
                thresh = 0,
                cmap = 'Blues',
                ax = axes[0,0])
k1b = sns.kdeplot(x=movies.BudgetMillions,y= movies.AudienceRating,
                 cmap = 'cool',
                 linewidths=1,ax = axes[0,0])     #useful for giving borders

k2 = sns.kdeplot(x=movies.BudgetMillions,
                 y=movies.CriticRating,
                shade = True,
                thresh = 0,
                cmap = 'inferno',
                ax = axes[0,1])
k2b = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,
                 cmap='cool',linewidths=1, ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

k3 = sns.violinplot(data=movies[movies.Genre=='Drama'],
                   x = 'Year', y = 'CriticRating',palette='Set1',
                   ax = axes[1,0])

k4 = sns.kdeplot(x = movies.CriticRating,
                y = movies.AudienceRating,
                shade = True, thresh = 0, cmap = 'Blues_r',ax = axes[1,1])
k4b = sns.kdeplot(x = movies.CriticRating,
                y = movies.AudienceRating,
                cmap = 'gist_gray_r',ax = axes[1,1])


plt.show()

# %% [markdown]
# * 1> category datatype in python
# * 2> jointplots
# * 3> histogram
# * 4> stacked histograms
# * 5> Kde plot
# * 6> subplot
# * 7> violin plots
# * 8> Factet grid
# * 9> Building dashboards
