# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
titanic = pd.read_csv(r"D:\Naresh It Classes\August\13th Spyder, Scikit-learn\TITANIC PROJECT\DATASET\titanic dataset.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
del titanic['Name']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del titanic['Ticket']
del titanic['Fare']
del titanic['Cabin']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
def getnumber(str):
    if str=='male':
        return 1
    else:
        return 2
titanic['Gender'] = titanic['Sex'].apply(getnumber)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3    male  22.0      1      0        S       1
# 1            2         1       1  female  38.0      1      0        C       2
# 2            3         1       3  female  26.0      0      0        S       2
# 3            4         1       1  female  35.0      1      0        S       2
# 4            5         0       3    male  35.0      0      0        S       1

# %%
del titanic['Sex']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3  22.0      1      0        S       1
# 1            2         1       1  38.0      1      0        C       2
# 2            3         1       3  26.0      0      0        S       2
# 3            4         1       1  35.0      1      0        S       2
# 4            5         0       3  35.0      0      0        S       1

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
meanS = titanic[titanic.Survived == 1].Age.mean()
meanS
# Out:
# 28.343689655172415

# %% [markdown]
# Fill the null values of the Age column. Fill mean Survived age(mean age of the survived people) in the column where the person has survived and mean not Survived age (mean age of the people who have not survived) in the column where person has not survived.
#
# Creating a new "Age" column , filling values in it with a condition if goes True then given values (here meanS or meanNS) is put in place of last values else nothing happens, simply the values are copied from the "Age" column of the dataset

# %%
titanic['age'] = np.where(pd.isnull(titanic.Age) & titanic['Survived']==1, meanS,titanic['Age'])
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0              1         0       3  22.0      1      0        S       1  22.0
# 1              2         1       1  38.0      1      0        C       2  38.0
# 2              3         1       3  26.0      0      0        S       2  26.0
# 3              4         1       1  35.0      1      0        S       2  35.0
# 4              5         0       3  35.0      0      0        S       1  35.0
# ..           ...       ...     ...   ...    ...    ...      ...     ...   ...
# 886          887         0       2  27.0      0      0        S       1  27.0
# 887          888         1       1  19.0      0      0        S       2  19.0
# 888          889         0       3   NaN      1      2        S       2   NaN
# 889          890         1       1  26.0      0      0        C       1  26.0
# 890          891         0       3  32.0      0      0        Q       1  32.0
#
# [891 rows x 9 columns]

# %%
meanNS = titanic[titanic.Survived==0].Age.mean()
meanNS
# Out:
# 30.62617924528302

# %%
titanic.age.fillna(meanNS,inplace=True)
titanic
# Out:
# C:\Users\Sheetal\AppData\Local\Temp\ipykernel_31056\1051471613.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic.age.fillna(meanNS,inplace=True)
#      PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender  \
# 0              1         0       3  22.0      1      0        S       1
# 1              2         1       1  38.0      1      0        C       2
# 2              3         1       3  26.0      0      0        S       2
# ...

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age              0
# dtype: int64

# %%
# del titanic['Age']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
survivedQ = titanic[titanic.Embarked == 'Q'][titanic.Survived==1].shape[0]
survivedC = titanic[titanic.Embarked == 'C'][titanic.Survived==1].shape[0]
survivedS = titanic[titanic.Embarked == 'S'][titanic.Survived==1].shape[0]
print(survivedQ)
print(survivedC)
print(survivedS)
# Out:
# 30
# 93
# 217
# C:\Users\Sheetal\AppData\Local\Temp\ipykernel_31056\4211347643.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedQ = titanic[titanic.Embarked == 'Q'][titanic.Survived==1].shape[0]
# C:\Users\Sheetal\AppData\Local\Temp\ipykernel_31056\4211347643.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC = titanic[titanic.Embarked == 'C'][titanic.Survived==1].shape[0]
# C:\Users\Sheetal\AppData\Local\Temp\ipykernel_31056\4211347643.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS = titanic[titanic.Embarked == 'S'][titanic.Survived==1].shape[0]

# %%
survivedQ = titanic[titanic.Embarked == 'Q'][titanic.Survived==0].shape[0]
survivedC = titanic[titanic.Embarked == 'C'][titanic.Survived==0].shape[0]
survivedS = titanic[titanic.Embarked == 'S'][titanic.Survived==0].shape[0]
print(survivedQ)
print(survivedC)
print(survivedS)
# Out:
# 47
# 75
# 427
# C:\Users\Sheetal\AppData\Local\Temp\ipykernel_31056\2222035967.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedQ = titanic[titanic.Embarked == 'Q'][titanic.Survived==0].shape[0]
# C:\Users\Sheetal\AppData\Local\Temp\ipykernel_31056\2222035967.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC = titanic[titanic.Embarked == 'C'][titanic.Survived==0].shape[0]
# C:\Users\Sheetal\AppData\Local\Temp\ipykernel_31056\2222035967.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS = titanic[titanic.Embarked == 'S'][titanic.Survived==0].shape[0]

# %% [markdown]
# deleting some rows from total rows will not affect the result. So rather than trying to fill those null values with some vales. We can simply remove them.

# %%
titanic.dropna(inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender        age
# 0              1         0       3      1      0        S       1  22.000000
# 1              2         1       1      1      0        C       2  38.000000
# 2              3         1       3      0      0        S       2  26.000000
# 3              4         1       1      1      0        S       2  35.000000
# 4              5         0       3      0      0        S       1  35.000000
# ..           ...       ...     ...    ...    ...      ...     ...        ...
# 886          887         0       2      0      0        S       1  27.000000
# 887          888         1       1      0      0        S       2  19.000000
# 888          889         0       3      1      2        S       2  30.626179
# 889          890         1       1      0      0        C       1  26.000000
# 890          891         0       3      0      0        Q       1  32.000000
#
# [889 rows x 8 columns]

# %%
titanic.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       0
# Gender         0
# age            0
# dtype: int64

# %%
titanic.rename(columns={'age':'Age','Gender':'Sex'},inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age
# 0            1         0       3      1      0        S    1  22.0
# 1            2         1       1      1      0        C    2  38.0
# 2            3         1       3      0      0        S    2  26.0
# 3            4         1       1      1      0        S    2  35.0
# 4            5         0       3      0      0        S    1  35.0

# %% [markdown]
# inplace==>default False, Whether to modify the DataFrame rather than creating a new one. If True then value of copy is ignored.

# %%
def getEmb(str):
    if str=='S':
        return 1
    elif str=='Q':
        return 2
    else:
        return 3
titanic["Embark"] = titanic["Embarked"].apply(getEmb)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age  Embark
# 0            1         0       3      1      0        S    1  22.0       1
# 1            2         1       1      1      0        C    2  38.0       3
# 2            3         1       3      0      0        S    2  26.0       1
# 3            4         1       1      1      0        S    2  35.0       1
# 4            5         0       3      0      0        S    1  35.0       1

# %%
del titanic['Embarked']

# %%
titanic.rename(columns={'Embark':'Embarked'},inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch  Sex   Age  Embarked
# 0            1         0       3      1      0    1  22.0         1
# 1            2         1       1      1      0    2  38.0         3
# 2            3         1       3      0      0    2  26.0         1
# 3            4         1       1      1      0    2  35.0         1
# 4            5         0       3      0      0    1  35.0         1

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
males = (titanic['Sex']==1).sum()
females = (titanic['Sex']==2).sum()
print(males)
print(females)
# Out:
# 577
# 312

# %%
p=[males,females]
plt.pie(p,
       labels = ['Male','Female'],
       colors = ['red','blue'],
       explode = (0.15,0),    # How much the gap should me there between the pies
       startangle = 0)
plt.axis('equal')
# makes the scales of the x-axis and y-axis equal, ensuring that a circle appears as a circle and a square appears as a square, rather than being distorted due to different scaling on each axis.
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
MaleS = titanic[titanic.Sex==1][titanic.Survived==1].shape[0] # .shape[0] ==> number of rows or the size of the first dimension
MaleNS = titanic[titanic.Sex==1][titanic.Survived==0].shape[0]
FemaleS = titanic[titanic.Sex==2][titanic.Survived==1].shape[0]
FemaleNS = titanic[titanic.Sex==2][titanic.Survived==0].shape[0]
print(MaleS)
print(MaleNS)
print(FemaleS)
print(FemaleNS)
# Out:
# 109
# 468
# 231
# 81

# %%
chart = [MaleS,MaleNS,FemaleS,FemaleNS]
colors = ['blue','lightskyblue','red','lightpink']
labels = ['Male Survived','Males Dead','Females Survived','Females Dead']
explode = [0,0,0,0]
plt.pie(chart,labels=labels,
       colors=colors,
       explode=explode,
       startangle=0,
       autopct='%.2f%%')
plt.axis('equal')
plt.show()
