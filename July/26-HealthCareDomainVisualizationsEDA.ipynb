# %% [markdown]
# # EDA of the heart disease dataset
# **Exploratory Data Analysis** or **EDA** is a critical first step in analyzing a new dataset. The primary objective of EDA is to analyze the data for distribution, outliers and anomalies in the dataset. It enable us to direct specific testing of the hypothesis. It includes analysing the data to find the distribution of data, its main characteristics, identifying patterns and visualizations.  It also provides tools for hypothesis generation by visualizing and understanding the data through graphical representation.

# %% [markdown]
# ## Objectives of EDA
#
# The objectives of the EDA are as follows:-
#
# i. To get an overview of the distribution of the dataset.
#
# ii. Check for missing numerical values, outliers or other anomalies in the dataset.
#
# iii.Discover patterns and relationships between variables in the dataset.
#
# iv. Check the underlying assumptions in the dataset.

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Naresh It Classes\July\26th Advanced EDA project-2\EDA- HEALTHCARE DOMAIN\heart.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.shape
# Out:
# (303, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.describe(include ='all')
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# # 1) Univariate Analysis
# -	Our feature variable of interest is `target`.
#
# -   It refers to the presence of heart disease in the patient.
#
# -   It is integer valued as it contains two integers 0 and 1 - (0 stands for absence of heart disease and 1 for presence of heart disease).

# %%
df['target'].nunique()
# Out:
# 2

# %%
df['target'].unique()   #So, the unique values are 1 and 0. (1 stands for presence of heart disease and 0 for absence of hear disease).
# Out:
# array([1, 0], dtype=int64)

# %%
df['target'].value_counts()
# 1 stands for presence of heart disease. 
# So, there are 165 patients suffering from heart disease.

# Similarly, 0 stands for absence of heart disease. 
# So, there are 138 patients who do not have any heart disease.
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize = (8,6))
ax = sns.countplot(x='target',data=df)
plt.show()

# plt.subplots(): This function creates a figure and a set of subplots. 
# By default, it creates a single subplot unless you specify nrows and ncols.

# %%
import seaborn as sns

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
# (1 = male; 0 = female)
# (1 = Presence of heart disease; 0 = Absence of heart disease)

# %%
f, ax = plt.subplots(figsize = (8,6))
ax = sns.countplot(x='sex',hue='target',data=df)
plt.show()

# %%
a = sns.catplot(x='target',col='sex',data=df, kind='count', height=5,aspect=1)

# It tells catplot to create a separate subplot (a "column" of plots) for each unique value in the sex column of your df DataFrame.
# "count" means that each subplot will be a count plot
# This argument controls the aspect ratio of each individual facet.
# aspect = width / height. So, aspect=1 means the width of each facet will be equal to its height (height * 1 = height).

# %%
a = sns.catplot(x='target',col='sex',data=df, kind='count', height=5,aspect=1.5)

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(y="target", hue="sex", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=df, facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette("dark", 3))
plt.show()

# %% [markdown]
# facecolor=(0, 0, 0, 0): => This is a new and interesting parameter.
# facecolor controls the fill color of the bars.
# (0, 0, 0, 0) is an RGBA tuple, where R=Red, G=Green, B=Blue, and A=Alpha (transparency).
# (0, 0, 0) means black, but the last 0 in the tuple means alpha (opacity) is 0. An alpha of 0 makes the color completely transparent.
#
# Effect: The bars will have no internal fill color; they will be transparent.

# %%
f,ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x = 'target', data = df,
                  facecolor = (0,0,0,0),
                  linewidth = 5,
                  edgecolor = sns.color_palette('dark'))
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax = sns.countplot(x='target',hue='fbs',data=df)
plt.show()

# %%
f,ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='target',hue='exang',data=df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# # 2) Bivariate Analysis
# The target variable is target. So, we should check how each attribute correlates with the target variable.
#
# The index of this Pandas Series will be the names of the other variables, and the values will be their respective correlations with 'target'.
#
# This will give you a clear ranking of all features based on how strongly (positively or negatively) they are linearly correlated with your target variable, making it easy to identify potentially important features.

# %%
correlation = df.corr()

# %%
correlation['target'].sort_values
# Out:
# <bound method Series.sort_values of age        -0.225439
# sex        -0.280937
# cp          0.433798
# trestbps   -0.144931
# chol       -0.085239
# fbs        -0.028046
# restecg     0.137230
# thalach     0.421741
# exang      -0.436757
# oldpeak    -0.430696
# slope       0.345877
# ca         -0.391724
# thal       -0.344029
# target      1.000000
# Name: target, dtype: float64>

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %% [markdown]
# #### cp stands for chest pain type.

# %%
df['cp'].nunique()
# Out:
# 4

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f,ax = plt.subplots(figsize=(10,8))
ax = sns.countplot(data=df,x='cp',palette='Set1')
plt.show()

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
f,ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='cp',data=df,hue='target')
plt.show()

# %% [markdown]
# ##### target variable contains two integer values 1 and 0 : (1 = Presence of heart disease; 0 = Absence of heart disease)

# %%
ax = sns.catplot(x='target',col='cp',data=df,kind='count',height=10,aspect=1)
plt.show()

# %%
ax = sns.catplot(x='target',col='cp',data=df,kind='strip',height=10,aspect=1)
plt.show()

# %%
ax = sns.catplot(x='target',col='cp',data=df,kind='box',height=10,aspect=1)
plt.show()

# %%
df['thalach'].nunique()
# Out:
# 91

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.distplot(x=df['thalach'],bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.distplot(x=df['thalach'],bins=10)
ax.set_xlabel('ThVar')
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.distplot(x=df['thalach'],bins=10,vertical=True)
ax.set_xlabel('ThVar')
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.kdeplot(x=df['thalach'],label='This is Thalach Variable')
ax.set_xlabel('ThVar')
plt.legend()
plt.show()

# %%
# when we give x & y values both are specified in the kde plots, then the graphs is like this with peaks and dips,
# when only 1 value is specified, then kde plot will be like a line graph

f,ax=plt.subplots(figsize=(8,6))
ax=sns.kdeplot(x=df['thalach'],y=df['target'],label='This is Thalach Variable')
ax.set_xlabel('ThVar')
plt.legend()
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.kdeplot(x=df['thalach'],label='This is Thalach Variable',color='red',shade=True)
ax.set_xlabel('ThVar')
plt.legend()
plt.show()

# %%
f,ax = plt.subplots(figsize=(10,6))
ax = sns.distplot(df['thalach'],kde=True,rug=True,bins=10)
plt.show()

# sns.distplot() function again, which is a powerful function for visualizing univariate distributions in Seaborn, although, as mentioned before, it's considered deprecated in newer versions of Seaborn (prefer sns.histplot and sns.kdeplot).
# rug=True means that small vertical lines (or "rug marks") will be drawn along the x-axis, with each line representing the location of an individual data point.
# Purpose: A rug plot helps to show the actual data points that contribute to the histogram bins and the KDE curve. Areas with a higher density of rug marks correspond to higher bars in the histogram and higher points on the KDE curve. 
# It can be useful for seeing the raw data points directly on the distribution plot.

# %%
f,ax = plt.subplots(figsize=(10,6))
ax = sns.distplot(df['thalach'],kde=False,rug=True,bins=10)
plt.show()

# %%
f,ax = plt.subplots(figsize=(8,6))
ax = sns.stripplot(data=df, x='target', y='thalach')
plt.show()

# %%
f,ax = plt.subplots(figsize=(8,6))
ax = sns.stripplot(data=df, x='target', y='thalach',jitter=0.01)
plt.show()

# %%
f,ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(data=df, x='target', y='thalach')
plt.show()

# %% [markdown]
# - There is no variable which has strong positive correlation with `target` variable.
#
# - There is no variable which has strong negative correlation with `target` variable.
#
# - There is no correlation between `target` and `fbs`.
#
# - The `cp` and `thalach` variables are mildly positively correlated with `target` variable.
#
# - We can see that the `thalach` variable is slightly negatively skewed.

# %% [markdown]
# # 3) Multivariate Analysis
# An important step in EDA is to discover patterns and relationships between variables in the dataset.

# %% [markdown]
# #### Heat map
# A heatmap is a graphical representation of data where the individual values contained in a matrix are represented as colors.
# It's excellent for visualizing correlation matrices.
#
# the values in the cells represent the correlation coefficients between those variables.
# the actual correlation coefficient will be displayed inside each cell.
#
# .2f means that the numerical annotations will be formatted as a floating-point number with exactly two decimal places

# %%
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a = sns.heatmap(
    correlation, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(),rotation=90)
a.set_yticklabels(a.get_yticklabels(),rotation=30)
plt.show()

# %%
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a = sns.heatmap(
    correlation, square=True, fmt='.2f',cmap='Blues')
a.set_xticklabels(a.get_xticklabels(),rotation=90)
a.set_yticklabels(a.get_yticklabels(),rotation=30)
plt.show()

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(df[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.set_style('whitegrid')
sns.pairplot(df[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %%
df['age'].nunique()
# Out:
# 41

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
df['age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 303 entries, 0 to 302
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 303 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB

# %%
f,ax=plt.subplots(figsize=(10,6))
ax = sns.distplot(df['age'],bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=sns.stripplot(x='target',y='age',data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=sns.boxplot(x='target',y='age',data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
ax=sns.scatterplot(x='age',y='trestbps',data=df)
plt.show()

#The scatter plot shows that there is no correlation between age and trestbps variable.

# %%
f,ax=plt.subplots(figsize=(10,6))
ax=sns.regplot(x='age',y='trestbps',data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
ax=sns.scatterplot(x='age',y='chol',data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
ax=sns.regplot(x='age',y='chol',data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
ax=sns.scatterplot(x='chol',y='thalach',data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
ax=sns.regplot(x='chol',y='thalach',data=df)
plt.show()

# %% [markdown]
# # 4) Dealing with missing values

# %%
df.isnull()
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# ..     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 298  False  False  False     False  False  False    False    False  False
# 299  False  False  False     False  False  False    False    False  False
# 300  False  False  False     False  False  False    False    False  False
# 301  False  False  False     False  False  False    False    False  False
# 302  False  False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().values.sum()
# Out:
# 0

# %% [markdown]
# our dataset has no missing values.
#
# **Assert statement** will return nothing if the value being tested is true and will throw an AssertionError if the value is false.
#
# - **Asserts**
#
#   - assert 1 == 1 (return Nothing if the value is True)
#
#   - assert 1 == 2 (return AssertionError if the value is False)
#
#  We can use an assert statement to programmatically check that no missing, unexpected 0 or negative values are present.

# %%
assert pd.notnull(df).all().all()
#assert that there are no missing values in the dataframe

# %%
assert (df>0).all().all()
#assert all values are greater than or equal to 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 assert (df>0).all().all()
#
# AssertionError:

# %%
assert (df>=0).all().all()

# %%
# there are no missing or negative values in the dataset.

# All the values are greater than or equal to zero.

# %% [markdown]
# # 5) Outlier Detection
# boxplots are used to visualize the outliers

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax = sns.boxplot(x = df['age'])
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax = sns.boxplot(y = df['age'])
plt.show()

# %%
df['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f,ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(x=df['trestbps'])
plt.show()

# the circles are outliers

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df["chol"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df["thalach"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df["oldpeak"])
plt.show()
